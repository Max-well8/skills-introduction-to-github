# %% [markdown]
# <a href="https://colab.research.google.com/github/Max-well8/skills-introduction-to-github/blob/main/Max_cal_for_salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def take_home_salary():


 Gross_earning=float(input("Enter your salary expectated: ",))


 tax=float(input("Enter your tax: ", ))

 Deduction=float(input("Enter an integer: ", ))


 Cal_salary=((Gross_earning)-(Deduction+tax))

 return Cal_salary

Net_salary=take_home_salary()
print("Salary to take home: ",Net_salary)
# Out:
# Enter your salary expectated: 8000
# Enter your tax: 600
# Enter an integer: 2000
# Salary to take home:  5400.0
